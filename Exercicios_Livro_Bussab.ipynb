# %% [markdown]
# Contou se o número de erros de impressão da primeira pagina de um jornal durante 50 dias, obtendo-se os resultados abaixo:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


erros = [8, 11, 8, 12, 14, 13, 11, 14, 14, 15, 6, 10, 14, 19, 6, 12, 7, 5, 8, 8, 10, 16, 10, 12, 12, 8, 11, 6, 7, 12, 7, 10, 14, 5, 12, 7, 9, 12, 11, 9, 14, 8, 14, 8, 12, 10, 12, 22, 7, 15]
dias = [i for i in range(len(erros))]
dfe = pd.DataFrame({"Erros":erros,"Dia":dias})

dfe.head()
# Out:
#    Erros  Dia
# 0      8    0
# 1     11    1
# 2      8    2
# 3     12    3
# 4     14    4

# %%
fig = plt.figure(figsize=(12,8))
dfe.Erros.value_counts(normalize=True).plot(kind='bar')
plt.title('Numero de erros de impressão da 1º pagina de um jornal durante 50 dias')
# Out:
# Text(0.5, 1.0, 'Numero de erros de impressão da 1º pagina de um jornal durante 50 dias')

# %%
dfe.Erros.hist()

# %%
from scipy.stats import norm

sns.distplot(dfe.Erros,fit=norm)

# %%
sns.lineplot(dfe.Dia,dfe.Erros)

# %%
#As taxas médias geométricas de incremento anual(por 100 habitantes) dos 30 maiores municípios do Brasil estão dadas  abaixo

geotax = [3.67, 1.82, 3.74, 4.10, 4.30,
          1.28, 8.14, 2.43, 4.17, 5.36,
          3.96, 6.54, 5.84, 7.35, 3.63,
          2.93, 2.82, 8.45, 5.28, 5.41,
          7.77, 4.65, 1.88, 2.12, 4.26,
          2.78, 5.54, 0.90, 5.09, 4.07]

dfgeo = pd.DataFrame({'Incremento Geometrico':geotax})

#histograma
dfgeo['Incremento Geometrico'].hist()
